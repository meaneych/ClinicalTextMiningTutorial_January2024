# %%
#############################################################################
## Demo the USVA Hospitals COVID-19 BioSurveillance App
##
## Name: Chris Meaney
## Date: June 2021
#############################################################################

# %%
## Package dependencies
import pandas as pd

## For sessionInfo
from sinfo import sinfo

## For printing 
from pprint import pprint

## For NLP and clinical NLP (covid19 biosurveillance) 
import spacy
import medspacy
import cov_bsv

from medspacy.visualization import visualize_dep

# %%
## To suppress warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\ChristopherMeaney\anaconda3\envs\pyenv_usva_covid\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
## Pandas Options (for print dataFrames to console)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 500)

# %%
## Import test strings
fpath = 'C:\\Users\\ChristopherMeaney\\Desktop\\Phenotype_COVID\\template_covid_test_strings_wch_cmedits.csv'
X = pd.read_csv(filepath_or_buffer=fpath)
X.shape
# Out:
# (82, 1)

# %%
## Print head of file to console
X.head(n=5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                  cleaned_value
# 0                                    COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 1  COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.
# 2                                                                                                                                                                                                                                                                                                                                                                                      No swab
# 3                                                                   COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Luminex ARIES 2019-nCoV Assay.,NOTE: The Luminex ARIES 2019-nCoV Assay has not been,approved by Health Canada but has been verified by the,University Health Network/Sinai Health Microbiology,Laboratory.
# 4                                                                                                                                                                                                                                                                                                                                                                                     negative

# %%
## Convert to list structure
texts = X.cleaned_value.to_list()
len(texts)
# Out:
# 82

# %%
##############################################
## Apply cov_bsv and medspacy to texts
##############################################

# %%
nlp = cov_bsv.load()

# %%
nlp

# %%
nlp.pipe_names
# Out:
# ['tagger',
#  'parser',
#  'concept_tagger',
#  'target_matcher',
#  'sectionizer',
#  'context',
#  'postprocessor',
#  'document_classifier']

# %%
## Here we actually apply NLP processing function over corpus
docs = list(nlp.pipe(texts))

# %%
################################################
## What is classification of each document - this is main function in cov_bsv (i.e. document classification of COVID-19 post/neg/unk)
################################################
docs_classify = [doc._.cov_classification for doc in docs]
X['classify'] = docs_classify

# %%
## Print document and its classification to console
X
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           cleaned_value  \
# 0                                                                                                                                                             COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 1                                                                                                                           COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               No swab
# 3                                                                                                                                                                                            COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Luminex ARIES 2019-nCoV Assay.,NOTE: The Luminex ARIES 2019-nCoV Assay has not been,approved by Health Canada but has been verified by the,University Health Network/Sinai Health Microbiology,Laboratory.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              negative
# 5                                                                                                                                                                              COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,By the Altona RealStar SARS-CoV-2 RT-PCR Kit 1.0.,NOTE: The Altona RealStar SARS-CoV-2 RT-PCR Kit 1.0,has been verified at the University Health Network,Sinai Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 6                                                                                                                                                                               COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the cobas SARS-COV-2 Assay.,NOTE: The cobas SARS-COV-2 Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 7                                                                                                                                                                                     COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the BGI 2019-nCoV Assay.,NOTE: The BGI 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 8                                                                                                                                                                   COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 9                                                                                                                           COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the BGI Real-Time Fluorescent RT-PCR,2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 10                                                COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,COVID-19 virus RdRp gene: NOT detected,COVID-19 virus Envelope gene: NOT detected,COVID-19 virus Nucleocapsid gene: NOT detected,based on testing by the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been verified,at the University Health Network/Sinai Health Microbiology,Laboratory.It has not been cleared or approved by Health,Canada.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             positive
# 12                                                                                                                                                                 COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Based on testing by the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been verified,at the University Health Network/Sinai Health Microbiology,Laboratory.It has been approved by Health Canada for,Emergency Use Access (EUA).
# 13                                                                                                                                                                                           COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Luminex ARIES 2019-nCoV Assay.,NOTE: The Luminex AREIS 2019-nCoV Assay has not been,approved by Health Canada but has been verified by the,University Health Network/Sinai Health Microbiology,Laboratory.
# 14                                COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,COVID-19 virus RdRp gene: NOT detected,COVID-19 virus Envelope gene: NOT detected,COVID-19 virus Nucleocapsid gene: NOT detected,based on testing by the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been verified,at the University Health Network/Sinai Health Microbiology,Laboratory.It has been approved by Health Canada for,Emergency Use Access (EUA).
# 15                                                                                                                                                                   COVID-19 virus,DETECTED by real-time PCR,* * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 16              COVID-19 virus PCR test unable to be completed.,* * * * * * * * * * * * * * * * * * *,No gene targets were detected including the internal,control suggesting inhibition of the Seegene Allplex,2019-nCoV Assay PCR reaction. Please submit another,sample for testing if clinically indicated.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory
# 17                                                                                                                                                                                    COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * *,Testing performed using the Cobas SARS-COV-2 Assay.,NOTE: The Cobas SARS-COV-2 Assay has been approved by Health,Canada for Emergency Use Access (EUA) and has been verified,by the University Health Network/Sinai Health Microbiology,Laboratory.
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             negative
# 19                                                                  COVID-19 virus,DETECTED by real-time PCR,* * * * * * * * * * * * * * * * * *,COVID-19 virus RdRp gene: DETECTED,COVID-19 virus Envelope gene: DETECTED,COVID-19 virus Nucleocapsid gene: DETECTED,based on testing by the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been,verified by the University Health Network/Sinai,Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 20                                                                                                                                                                                                 COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,Testing performed using the Luminex ARIES 2019-nCoV Assay.,NOTE: The Luminex ARIES 2019-nCoV Assay has not been,approved by Health Canada but has been verified by the,University Health Network/Sinai Health Microbiology,Laboratory.
# 21                                                                                                                                COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.
# 22                                                                                                                                                                    COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,based on testing by the Luminex AREIS SARS-CoV-2 RT-PCR,Assay.,NOTE: The Luminex AREIS SARS-CoV-2 RT-PCR Assay has been,verified by the University Health Network/Sinai Health,Microbiology,Laboratory. It has not been cleared or approved by Health,Canada.
# 23                                                                                                                                                                                   COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,By the Altona RealStar SARS-CoV-2 RT-PCR Kit 1.0.,NOTE: The Altona RealStar SARS-CoV-2 RT-PCR Kit 1.0,has been verified at the University Health Network,Sinai Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 24                                                                                                                                                                  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,based on testing by the Altona,RealStar SARS-CoV-2 RT-PCR Kit 1.0.,NOTE: The Altona RealStar SARS-CoV-2 RT-PCR Kit 1.0 has,been verified at the University Health Network/Sinai,Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 25                                                                                                                                   COVID-19 virus,DETECTED by real-time PCR.,(Low level detection confirmed),* * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory
# 26                                                                                                                                                                   COVID-19 virus,DETECTED by real-time PCR,* * * * * * * * * * * * * * * * * *,based on testing by the Altona,RealStar SARS-CoV-2 RT-PCR Kit 1.0.,NOTE: The Altona RealStar SARS-CoV-2 RT-PCR Kit 1.0 has,been verified at the University Health Network/Sinai,Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 27                                                                                                                                                                                                 COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,Testing performed using the Luminex ARIES 2019-nCoV Assay.,NOTE: The Luminex AREIS 2019-nCoV Assay has not been,approved by Health Canada but has been verified by the,University Health Network/Sinai Health Microbiology,Laboratory.
# 28                                                                                                                                                                                                                                                                                                         COVID-19 virus PCR test unable to be completed.,Specimen was documented as collected but not received,by the Microbiology Laboratory after 7 days. If this test,is still required, please place a new order.
# 29                                                          COVID-19 virus,DETECTED by real-time PCR,* * * * * * * * * * * * * * * * * *,COVID-19 virus RdRp gene: NOT DETECTED,COVID-19 virus Envelope gene: NOT DETECTED,COVID-19 virus Nucleocapsid gene: DETECTED,based on testing by the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been,verified by the University Health Network/Sinai,Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 30                                                                                                                                                                              COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Cobas SARS-COV-2 Assay.,NOTE: The Cobas SARS-COV-2 Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 31                                                          COVID-19 virus,DETECTED by real-time PCR,* * * * * * * * * * * * * * * * * *,COVID-19 virus RdRp gene: Not detected,COVID-19 virus Envelope gene: Not detected,COVID-19 virus Nucleocapsid gene: DETECTED,based on testing by the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been,verified by the University Health Network/Sinai,Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 32  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.,Indeterminate for COVID-19 virus.,* * * * * * * * * * * * * * * * * * *,Results sh...
# 33  Indeterminate for COVID-19 virus.,* * * * * * * * * * * * * * * * * * *,Results should be interpreted within the context of the,clinical signs, symptoms, and history of the patient.,INDETERMINATE result may indicate the presence of low levels,of virus, non-specific reactivity of the assay, or other,unrecognized factors. Please submit a follow-up sample if,clinically indicated.,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been appr...
# 34                                                          COVID-19 virus PCR test unable to be completed.,* * * * * * * * * * * * * * * * * * *,No gene targets were detected including the internal,control suggesting inhibition of the ARIES 2019-nCOV,PCR reaction. Please submit another,sample for testing if clinically indicated.,NOTE: The Luminex ARIES 2019-nCoV Assay has not been,approved by Health Canada but has been verified by the,University Health Network/Sinai Health Microbiology,Laboratory.
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                COVID-19 virus PCR test unable to be completed.,Specimen not received
# 36                                                                                                                                            COVID-19 virus,DETECTED by real-time PCR.,(Low level detection),* * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 37  COVID-19 virus,(Low level detection),Sample is being retested. Further report to follow.,* * * * * * * * * * * * * * * * * *,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.,INDETERMINATE for COVID-19 virus.,* * * * * * * * * * * * * * * * * * *,Res...
# 38  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.,UPDATED REPORT,Indeterminate for COVID-19 virus.,* * * * * * * * * * * * * * * * *...
# 39                                                                                                                                                                                                                                                                                                                                                                                                  No specimen with this patient's name was received.,Please repeat if necessary.,(Unlabeled specimen received by lab)
# 40                                                                                                                                                                           COVID-19 virus,DETECTED by real-time PCR,* * * * * * * * * * * * * * * * * *,based on testing by the Luminex AREIS SARS-CoV-2 RT-PCR,Assay.,NOTE: The Luminex AREIS SARS-CoV-2 RT-PCR Assay has been,verified by the University Health Network/Sinai Health,Microbiology,Laboratory. It has not been cleared or approved by Health,Canada.
# 41  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.,COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * ...
# 42                                                                        COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,COVID-19 virus SARS-CoV-2(S gene): DETECTED,COVID-19 virus B- Beta CoV (E gene): DETECTED,based on testing by the Altona,RealStar SARS-CoV-2 RT-PCR Kit 1.0.,NOTE: The Altona RealStar SARS-CoV-2 RT-PCR Kit 1.0 has,been verified at the University Health Network/Sinai,Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 43  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.,COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The S...
# 44                                                                                                                                            COVID-19 virus,DETECTED by real-time PCR.,(Low level detection) * * * * * * * * * * * *,* * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 45                                                                                                                                                                                  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the cobas SARS-COV-2 Assay.,NOTE: The cobas SARS-COV-2 Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 46                                                      COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.
# 47  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.,INDETERMINATE for COVID-19 virus.,* * * * * * * ...
# 48  COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Luminex ARIES 2019-nCoV Assay.,NOTE: The Luminex ARIES 2019-nCoV Assay has not been,approved by Health Canada but has been verified by the,University Health Network/Sinai Health Microbiology,Laboratory.,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been...
# 49                                                                                 COVID-19 virus PCR test unable to be completed.,Specimen tube not labelled,COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 50                                          COVID-19 virus,DETECTED by real-time PCR,* * * * * * * * * * * * * * * * * *,COVID-19 virus RdRp gene: NOT DETECTED,COVID-19 virus Envelope gene: NOT DETECTED,COVID-19 virus Nucleocapsid gene: DETECTED,based on testing by the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been,verified by the University Health Network/Sinai,Health Microbiology Laboratory.,It has been approved by Health Canada for Emergency,Use Access (EUA).
# 51  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.,COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * ...
# 52                                                                                                                                                                                      COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,Testing performed using the Cobas SARS-COV-2 Assay.,NOTE: The Cobas SARS-COV-2 Assayhas been approved by Health,Canada for Emergency Use Access(EUA) and has been verified by,the University Health Network/Sinai Health Microbiology,Laboratory.
# 53                                                                                                                            Updated report,Result to follow,COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 54                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              No swab
# 55                                                                       COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the BGI Real-Time Fluorescent RT-PCR,2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.,For any Repeats: Report result as per Seegene SOP.
# 56  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.,COVID-19 virus NOT detected by real-time PCR.,* ...
# 57                                COVID-19 virus PCR test unable to be completed.,* * * * * * * * * * * * * * * * * * *,No gene targets were detected including the internal,control suggesting inhibition of the cobas SARS-COV-2,Assay PCR reaction. Please submit another,sample for testing if clinically indicated.,NOTE: The cobas SARS-COV-2 Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory
# 58                                                                    COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,COVID-19 virus SARS-CoV-2(S gene): DETECTED,COVID-19 virus B- Beta CoV (E gene): NOT detected,based on testing by the Altona,RealStar SARS-CoV-2 RT-PCR Kit 1.0.,NOTE: The Altona RealStar SARS-CoV-2 RT-PCR Kit 1.0 has,been verified at the University Health Network/Sinai,Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                 Not tested. Specimen received is unlabelled.,Unsuitable for testing.
# 60                                                                                                                                                                                                                                                                                                                                                                                                                                                     COVID-19 virus PCR test unable to be completed.,Duplicate sample
# 61                                  COVID-19 virus PCR test unable to be completed.,Request form was received in Microbiology Lab but no specimen,in the bag.,COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 62                                                          COVID-19 virus,DETECTED by real-time PCR,* * * * * * * * * * * * * * * * * *,COVID-19 virus RdRp gene: NOT detected,COVID-19 virus Envelope gene: NOT detected,COVID-19 virus Nucleocapsid gene: DETECTED,based on testing by the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been,verified by the University Health Network/Sinai,Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 63                                                                                                                                                                COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,Testing performed using the BGI Real-Time Fluorescent RT-PCR,2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai
# 64  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,* * * * * * * * * * * * * * * * * *,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.,INDETERMINAT...
# 65  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.,COVID-19 virus NOT detected by real-time PCR.,* ...
# 66  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.,Indeterminate for COVID-19 virus.,* * * * * * * ...
# 67                                                                                                                                                                                                                                                                                                                                                    This specimen was documented as collected but not received,by the Microbiology Laboratory after 7 days. If this test,is still required, please place a new order.
# 68  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,* * * * * * * * * * * * * * * * * *,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.,INDETERMINAT...
# 69                                                              COVID-19 virus,DETECTED by real-time PCR,* * * * * * * * * * * * * * * * * *,COVID-19 virus RdRp gene: DETECTED,COVID-19 virus Envelope gene: NOT DETECTED,COVID-19 virus Nucleocapsid gene: DETECTED,based on testing by the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been,verified by the University Health Network/Sinai,Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 70                                                              COVID-19 virus,DETECTED by real-time PCR,* * * * * * * * * * * * * * * * * *,COVID-19 virus RdRp gene: DETECTED,COVID-19 virus Envelope gene: NOT detected,COVID-19 virus Nucleocapsid gene: DETECTED,based on testing by the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been,verified by the University Health Network/Sinai,Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.
# 71                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             positive
# 72                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            no result
# 73  COVID-19 virus PCR test unable to be completed.,* * * * * * * * * * * * * * * * * * *,No gene targets were detected including the human,beta-actin gene suggesting inhibition of the BGI Real-Time,Fluorescent RT-PCR 2019-nCoV Assay PCR reaction or inadequate,sampling. Please submit another sample for testing if,clinically indicated.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the Universit...
# 74                                                                                                                                                                           COVID-19 virus,COVID-19 virus DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,Testing performed using the BGI 2019-nCoV Assay.,NOTE: The BGI 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 75                                                                                                                                                                                                                                                                                                                                                                                                      POSITIVE - continuing positive was previously positive (prior to April 10)- reswabbed for work - should exclude
# 76  COVID-19 virus,DETECTED by real-time PCR.,* * * * * * * * * * * * * * * * * *,(Low level detection),Sample is being retested. Further report to follow.,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.,COVID-19 virus,DETECTED by real-time PCR.,(Low l...
# 77                                                                                                                                                                                                                                                                                                                                                                                                                                                                                No swab but swabbed twice subseqently
# 78                                                                                                                                                    Preop - COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 79                                                                                                                                                                                                                                                                                                                                                   This sample has been documented as collected but has not been,recieved by the Microbiology Lab after 6 days. If testing is,still required please recollect sample.
# 80                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      incomplete test
# 81                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              no swab
#
#    classify
# 0       UNK
# 1       UNK
# 2       NEG
# 3       UNK
# 4       NEG
# 5       UNK
# 6       UNK
# 7       UNK
# 8       POS
# 9       UNK
# 10      UNK
# 11      NEG
# 12      UNK
# 13      UNK
# 14      UNK
# 15      POS
# 16      UNK
# 17      UNK
# 18      NEG
# 19      POS
# 20      POS
# 21      POS
# 22      UNK
# 23      POS
# 24      POS
# 25      POS
# 26      POS
# 27      POS
# 28      UNK
# 29      POS
# 30      UNK
# 31      POS
# 32      POS
# 33      UNK
# 34      UNK
# 35      UNK
# 36      POS
# 37      UNK
# 38      POS
# 39      NEG
# 40      POS
# 41      POS
# 42      POS
# 43      POS
# 44      POS
# 45      POS
# 46      POS
# 47      POS
# 48      UNK
# 49      UNK
# 50      POS
# 51      POS
# 52      POS
# 53      UNK
# 54      NEG
# 55      UNK
# 56      POS
# 57      UNK
# 58      POS
# 59      NEG
# 60      UNK
# 61      UNK
# 62      POS
# 63      POS
# 64      POS
# 65      POS
# 66      POS
# 67      NEG
# 68      POS
# 69      POS
# 70      POS
# 71      NEG
# 72      NEG
# 73      UNK
# 74      POS
# 75      NEG
# 76      POS
# 77      NEG
# 78      UNK
# 79      NEG
# 80      NEG
# 81      NEG

# %%
X.classify.value_counts()
# Out:
# POS    38
# UNK    29
# NEG    15
# Name: classify, dtype: int64

# %%
#############################################
## Get COVID-19 entities/utterances in each doc
#############################################
covid_ents = [[ent for ent in doc.ents] for doc in docs]
len(covid_ents)
# Out:
# 82

# %%
## Print COVID-19 entities found in each document to console
pprint(covid_ents)
# Out:
# [[COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [],
#  [COVID-19, SARS-CoV-2, SARS-CoV-2],
#  [COVID-19, SARS-COV-2, SARS-COV-2],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, PCR,2019-nCoV, 2019-nCoV],
#  [COVID-19, COVID-19, COVID-19, COVID-19, 2019-nCoV, 2019-nCoV],
#  [],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, COVID-19, COVID-19, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, Allplex,2019-nCoV, 2019-nCoV],
#  [COVID-19, SARS-COV-2, SARS-COV-2],
#  [],
#  [COVID-19, COVID-19, COVID-19, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, SARS-CoV-2, SARS-CoV-2],
#  [COVID-19, SARS-CoV-2, SARS-CoV-2],
#  [COVID-19, SARS-CoV-2, SARS-CoV-2],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, SARS-CoV-2, SARS-CoV-2],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19],
#  [COVID-19, COVID-19, COVID-19, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, SARS-COV-2, SARS-COV-2],
#  [COVID-19, COVID-19, COVID-19, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCOV, 2019-nCoV],
#  [COVID-19],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV, COVID-19, 2019-nCoV, 2019-nCoV],
#  [],
#  [COVID-19, SARS-CoV-2, SARS-CoV-2],
#  [COVID-19,
#   2019-nCoV,
#   2019-nCoV,
#   2019-nCoV,
#   2019-nCoV,
#   COVID-19,
#   2019-nCoV,
#   2019-nCoV],
#  [COVID-19, COVID-19, COVID-19, SARS-CoV-2, SARS-CoV-2],
#  [COVID-19, 2019-nCoV, 2019-nCoV, 2019-nCoV, 2019-nCoV, COVID-19],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, SARS-COV-2, SARS-COV-2],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV, 2019-nCoV, 2019-nCoV],
#  [COVID-19, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, COVID-19, COVID-19, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19,
#   2019-nCoV,
#   2019-nCoV,
#   2019-nCoV,
#   2019-nCoV,
#   COVID-19,
#   2019-nCoV,
#   2019-nCoV,
#   COVID-19,
#   2019-nCoV,
#   2019-nCoV,
#   COVID-19,
#   COVID-19,
#   2019-nCoV,
#   2019-nCoV,
#   COVID-19],
#  [COVID-19, SARS-COV-2, SARS-COV-2],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [],
#  [COVID-19, PCR,2019-nCoV, 2019-nCoV],
#  [COVID-19,
#   2019-nCoV,
#   2019-nCoV,
#   2019-nCoV,
#   2019-nCoV,
#   COVID-19,
#   2019-nCoV,
#   2019-nCoV,
#   COVID19],
#  [COVID-19, SARS-COV-2],
#  [COVID-19, COVID-19, COVID-19, SARS-CoV-2, SARS-CoV-2],
#  [],
#  [COVID-19],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, COVID-19, COVID-19, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, PCR,2019-nCoV, 2019-nCoV],
#  [COVID-19, 2019-nCoV, 2019-nCoV, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19,
#   2019-nCoV,
#   2019-nCoV,
#   2019-nCoV,
#   2019-nCoV,
#   COVID-19,
#   2019-nCoV,
#   2019-nCoV,
#   COVID],
#  [COVID-19, 2019-nCoV, 2019-nCoV, COVID-19, PCR,2019-nCoV, 2019-nCoV],
#  [],
#  [COVID-19, 2019-nCoV, 2019-nCoV, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, COVID-19, COVID-19, COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, COVID-19, COVID-19, COVID-19, 2019-nCoV, 2019-nCoV],
#  [],
#  [],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [COVID-19, COVID-19, 2019-nCoV, 2019-nCoV],
#  [],
#  [COVID-19, 2019-nCoV, 2019-nCoV, 2019-nCoV, 2019-nCoV],
#  [],
#  [COVID-19, 2019-nCoV, 2019-nCoV],
#  [],
#  [],
#  []]

# %%
X['covid_ents'] = covid_ents
X.head(n=5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                  cleaned_value  \
# 0                                    COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Seegene Allplex 2019-nCoV Assay.,NOTE: The Seegene Allplex 2019-nCoV Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.
# 1  COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the BGI Real-Time Fluorescent,RT-PCR 2019-nCoV Assay.,NOTE: The BGI Real-Time Fluorescent RT-PCR 2019-nCoV Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.
# 2                                                                                                                                                                                                                                                                                                                                                                                      No swab
# 3                                                                   COVID-19 virus NOT detected by real-time PCR.,* * * * * * * * * * * * * * * * * * *,Testing performed using the Luminex ARIES 2019-nCoV Assay.,NOTE: The Luminex ARIES 2019-nCoV Assay has not been,approved by Health Canada but has been verified by the,University Health Network/Sinai Health Microbiology,Laboratory.
# 4                                                                                                                                                                                                                                                                                                                                                                                     negative
#
#   classify                              covid_ents
# 0      UNK  [(COVID-19), (2019-nCoV), (2019-nCoV)]
# 1      UNK  [(COVID-19), (2019-nCoV), (2019-nCoV)]
# 2      NEG                                      []
# 3      UNK  [(COVID-19), (2019-nCoV), (2019-nCoV)]
# 4      NEG                                      []

# %%
####################################################
## Visualize why NLP pipeline is making pos/neg/unk COVID-19 classifications
####################################################
for i, doc in enumerate(docs):
    cov_bsv.visualize_doc(doc, document_id=i)
    print("__"*20)
    visualize_dep(doc)
    print("__"*20)
# Out:
# <h2>Document Classification: UNK</h2><h3>Document ID: 0</h3><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  virus
# <mark class="entity" style="background: #ff7f0e; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NOT detected
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NEGATED_EXISTENCE</span>
# </mark>
#  by real-time
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PCR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
# .,* * * * * * * * * * * * * * * * * * *,
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Testing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
#  performed using the Seegene Allplex
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019-nCoV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  Assay.,NOTE: The Seegene Allplex
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019-nCoV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.</div>
# ________________________________________
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="659c471fa6b5440d9ba1af52ab6d03fe-0" class="displacy" width="13525" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">COVID-19</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">COVID-19</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">virus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">NOT detected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">real</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">PCR</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">Testing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="5475">performed</t
# ________________________________________
# <h2>Document Classification: UNK</h2><h3>Document ID: 1</h3><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  virus
# <mark class="entity" style="background: #ff7f0e; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NOT detected
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NEGATED_EXISTENCE</span>
# </mark>
#  by real-time
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PCR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
# .,* * * * * * * * * * * * * * * * * * *,Testing performed using the BGI Real-Time Fluorescent,RT-
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PCR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
#
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019-nCoV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  Assay.,NOTE: The BGI Real-Time Fluorescent RT-
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PCR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
#
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019-nCoV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  Assay,has been approved by Health Canada for Emergency Use Access,(EUA) and has been verified by the University Health,Network/Sinai Health Microbiology Laboratory.</div>
# ________________________________________
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="44af51e9f60d4e0d88a71275fc81d248-0" class="displacy" width="15275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">COVID-19</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">COVID-19</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">virus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">NOT detected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">real</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">PCR</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">Testing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="5475">performed</t
# ________________________________________
# <h2>Document Classification: NEG</h2><h3>Document ID: 2</h3><div class="entities" style="line-height: 2.5; direction: ltr">No swab</div>
# ________________________________________
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="73c7467a9ced41faa41300addeef3bba-0" class="displacy" width="400" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">No</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">swab</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
# </svg></span>
# ________________________________________
# <h2>Document Classification: UNK</h2><h3>Document ID: 3</h3><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  virus
# <mark class="entity" style="background: #ff7f0e; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NOT detected
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NEGATED_EXISTENCE</span>
# </mark>
#  by real-time
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PCR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
# .,* * * * * * * * * * * * * * * * * * *,Testing performed using the Luminex ARIES
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019-nCoV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  Assay.,NOTE: The Luminex ARIES
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019-nCoV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  Assay has not been,approved by Health Canada but has been verified by the,University Health Network/Sinai Health Microbiology,Laboratory.</div>
# ________________________________________
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4879c6e6f148478c84c9816eaa2745b1-0" class="displacy" width="12475" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">COVID-19</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">COVID-19</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">virus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">NOT detected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">real</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">PCR</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">Testing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="5475">performed</t
# ________________________________________
# <h2>Document Classification: NEG</h2><h3>Document ID: 4</h3><div class="entities" style="line-height: 2.5; direction: ltr">negative</div>
# ________________________________________
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b5ec265b20184ceead0e173c256da7c5-0" class="displacy" width="225" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">negative</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
# </svg></span>
# ________________________________________
# <h2>Document Classification: UNK</h2><h3>Document ID: 5</h3><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  virus
# <mark class="entity" style="background: #ff7f0e; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NOT detected
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NEGATED_EXISTENCE</span>
# </mark>
#  by real-time
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PCR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
# .,* * * * * * * * * * * * * * * * * * *,By the Altona RealStar
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SARS-CoV-2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  RT-
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PCR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
#  Kit 1.0.,NOTE: The Altona RealStar
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SARS-CoV-2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  RT-PCR Kit 1.0,has been verified at the University Health Network,Sinai Health Microbiology Laboratory.,It has not been cleared or approved by Health Canada.</div>
# ________________________________________
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e26a03cddc0d41848773ae5fc8c75d78-0" class="displacy" width="13000" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">COVID-19</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">COVID-19</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">virus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">NOT detected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">real</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">PCR</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">By</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="5475">the</tspan>
#     <
# ________________________________________
# <h2>Document Classification: UNK</h2><h3>Document ID: 6</h3><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  virus
# <mark class="entity" style="background: #ff7f0e; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NOT detected
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NEGATED_EXISTENCE</span>
# </mark>
#  by real-time
# <mark class="entity" style="background: #1f77b4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PCR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
# .,* * * * * * * * * * * * * * * * * * *,Testing performed using the cobas
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SARS-COV-2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  Assay.,NOTE: The cobas
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SARS-COV-2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COVID-19</span>
# </mark>
#  Assay has been approved,by Health Canada for Emergency Use Access (EUA) and has,been verified by the University Health Network/Sinai,Health Microbiology Laboratory.</div>
# ________________________________________
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e86c702c731e4253982d22f89360ec4f-0" class="displacy" width="13175" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">COVID-19</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">COVID-19</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">virus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">NOT detected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">real</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">PCR</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">*</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="5475">,</tspan>
# ________________________________________
# <h2>Document Classification: NEG</h2><h3>Document ID: 79</h3><div class="entities" style="line-height: 2.5; direction: ltr">This sample has been documented as collected but has not been,recieved by the Microbiology Lab after 6 days. If testing is,still required please recollect sample.</div>
# ________________________________________
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="533c1c8af164408dad4e6e35bb0a5e78-0" class="displacy" width="5475" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">sample</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">documented</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">collected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">recieved</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Microbiology</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Lab</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">after</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">days</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">If</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">testing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">still</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">required</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">please</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">recollect</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">sample</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300"></tspan>
# </text>
# </svg></span>
# ________________________________________
# <h2>Document Classification: NEG</h2><h3>Document ID: 80</h3><div class="entities" style="line-height: 2.5; direction: ltr">incomplete test</div>
# ________________________________________
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="881eda94521646a18525a08c4838571b-0" class="displacy" width="400" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">incomplete</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">test</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
# </svg></span>
# ________________________________________
# <h2>Document Classification: NEG</h2><h3>Document ID: 81</h3><div class="entities" style="line-height: 2.5; direction: ltr">no swab</div>
# ________________________________________
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6fcba5b625b849b787fc27cc1c32f24e-0" class="displacy" width="400" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">swab</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
# </svg></span>
# ________________________________________

# %%
#####################
## Session Info
#####################

# from sinfo import sinfo
sinfo()
# Out:
# -----
# cov_bsv     NA
# medspacy    0.1.0.0
# pandas      1.2.4
# sinfo       0.3.1
# spacy       2.3.2
# -----
# IPython             7.24.1
# jupyter_client      6.1.12
# jupyter_core        4.7.1
# jupyterlab          3.0.16
# notebook            6.4.0
# -----
# Python 3.7.10 | packaged by conda-forge | (default, Feb 19 2021, 15:37:01) [MSC v.1916 64 bit (AMD64)]
# Windows-10-10.0.19041-SP0
# 8 logical CPU cores, Intel64 Family 6 Model 126 Stepping 5, GenuineIntel
# -----
# Session information updated at 2021-06-24 12:30
